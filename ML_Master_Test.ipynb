# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=14)
sns.set(style='white')
sns.set(style='whitegrid', color_codes=True)
import warnings
import pickle
warnings.filterwarnings('ignore')

# %%
data = pd.read_pickle('year_five_df.pkl')

print(type(data))
data.head()
#drop 'Unnamed' index column
#in pull filter out memorials
#total funding column

for col in data.columns:
    print(col)

data.drop(['uuid', 'properties.name', 'properties.primary_role', 'properties.short_description', 'closed_on', 'acquired_by',
           'founders', 'funding_rounds', 'founded_on', 'is_closed', 'ipo', 'acquired_date', 'ipo_date', 'walkingdead_date',
          'founders_degree_info', 'founders_experience'], axis = 1, inplace = True)
    
# the following columns need to be made categorical
#City_name
#region_name
#categories
#news
#founders_degree_info
#founders_experience
#degree_types
#degree_subjects
#degree_schools
#job_titles

#drop the following
#unamed
#uuid
#properties.name
#properties.primary_role
#properties.short_description
#closed_on
#founded_on
#is_closed
#acquired_by
#founders
#funding_rounds
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# uuid
# properties.name
# properties.primary_role
# properties.short_description
# properties.city_name
# properties.region_name
# closed_on
# founded_on
# is_closed
# acquired_by
# categories
# founders
# funding_rounds
# ipo
# news
# founders_degree_info
# founders_experience
# acquired_date
# ipo_date
# walkingdead_date
# outcome
# degree_types
# degree_subjects
# degree_schools
# job_titles
# total_funding
#   properties.city_name properties.region_name  \
# 0              Jupiter                Florida
# 1              Orlando                Florida
# 2                Miami                Florida
# 3              Jackson                Wyoming
# 4      Fairfax Station               Virginia
#
#                                           categories news  outcome  \
# 0                                               [[]]    0        0
# 1         [Commerce and Shopping, Food and Beverage]    0        0
# ...

# %%
one_hot = preprocessing.MultiLabelBinarizer()
ohe_categories = one_hot.fit_transform(data['categories'])
ohe_categories_df = pd.DataFrame(ohe_categories, columns=one_hot.classes_)
data.join(pd.DataFrame(ohe_categories_df))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4d850658bf34> in <module>
#       1 one_hot = preprocessing.MultiLabelBinarizer()
# ----> 2 ohe_categories = one_hot.fit_transform(data['categories'])
#       3 ohe_categories_df = pd.DataFrame(ohe_categories, columns=one_hot.classes_)
#       4 data.join(pd.DataFrame(ohe_categories_df))
#
# c:\users\mrice\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\label.py in fit_transform(self, y)
#     869         class_mapping = defaultdict(int)
#     870         class_mapping.default_factory = class_mapping.__len__
# --> 871         yt = self._transform(y, class_mapping)
#     872
#     873         # sort classes and reorder columns
#
# c:\users\mrice\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\label.py in _transform(self, y, class_mapping)
# ...

# %%
one_hot.classes_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-596338211f57> in <module>
# ----> 1 one_hot.classes_
#
# AttributeError: 'MultiLabelBinarizer' object has no attribute 'classes_'

# %%
# Out:
# <class 'str'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'str'>
# <class 'list'>
# <class 'str'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'str'>
# <class 'str'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'str'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'str'>
# <class 'list'>
# <class 'list'>
# <class 'str'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'str'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'str'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'list'>
# ...
